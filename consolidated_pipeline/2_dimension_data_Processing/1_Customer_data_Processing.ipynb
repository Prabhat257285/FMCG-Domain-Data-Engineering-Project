# %%
# %python
from pyspark.sql.functions import *
from pyspark.sql.types import *
from delta.tables import *

# %%
# %run /Workspace/Users/prabhat257285@gmail.com/FMCG-Domain-Data-Engineering-Project/consolidated_pipeline/1_setup/Utilities

# %%
# %python
print(bronze_schema, silver_schema, gold_schema)

# %%
dbutils.widgets.text("catalog", "fmcg", "Catalog")
dbutils.widgets.text("data_source", "cutomers", "Data Source")

# %%
catalog = dbutils.widgets.get("catalog")
data_source = dbutils.widgets.get("data_source")

print(catalog, data_source)

# %%
base_path = f's3://sportchildbuk-dp/full_load/{data_source}/*.csv'
print(base_path)

# %%
base_path = f"s3://sportchildbuk-dp/full_load/{data_source}/*.csv"

df = (
    spark.read
    .format("csv")
    .option("header", "true")
    .option("inferSchema", "true")
    .load(base_path)
)

display(df.limit(10))
